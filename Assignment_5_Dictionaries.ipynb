# %% [markdown]
# <h1>python 5th assingment

# %% [markdown]
# ## Q1 Roll number dictionary

# %%
students={1:'A',2:'B',3:'C',4:'D',5:'E'}
print(students)
# Out:
# {1: 'A', 2: 'B', 3: 'C', 4: 'D', 5: 'E'}

# %% [markdown]
# ## Q2 Word frequency

# %%
s='hello world hello'
words=s.split()
freq={}
for i in words:
    freq[i]=freq.get(w,0)+1
print(freq)
# Out:
# {'hello': 2, 'world': 1}

# %% [markdown]
# ## Q3 Merge dictionaries

# %%
d1={'a':1}
d2={'b':2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %% [markdown]
# ## Q4 Max value key

# %%
d={'a':10,'b':50,'c':30}
print(max(d, key=d.get))
# Out:
# b

# %% [markdown]
# ## Q5 Key exists

# %%
d={'a':1,'b':2}
print('a' in d)
# Out:
# True
