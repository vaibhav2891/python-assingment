# %% [markdown]
# <h1>python 4th assingment

# %% [markdown]
# ## Q1 Union, Intersection, Difference

# %%
a={1,2,3}
b={3,4,5}
print('Union:',a|b)
print('Intersection:',a&b)
print('Difference:',a-b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}

# %% [markdown]
# ## Q2 Subset check

# %%
print({1,2}.issubset({1,2,3}))
# Out:
# True

# %% [markdown]
# ## Q3 Remove duplicates

# %%
lst=[1,2,2,3,3,4]
print(list(set(lst)))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ## Q4 Elements in first not in second

# %%
print({1,2,3,4}-{3,4})
# Out:
# {1, 2}

# %% [markdown]
# ## Q5 Disjoint

# %%
print({1,2}.isdisjoint({3,4}))
# Out:
# True
